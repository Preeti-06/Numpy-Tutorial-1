# %% [markdown]
# # 📝 NumPy Test – MCA 1st Year
#
# **Instructions:**
# - Solve all questions using NumPy.
# - Write clean and readable code.
# - Avoid explicit Python loops unless necessary.
# - Each question carries equal marks.

# %% [markdown]
# ## Import Required Library

# %%
import numpy as np

# %% [markdown]
# ## Question 1
# Create a NumPy array containing numbers from **1 to 20**.
# - Print the array
# - Print its **shape, size, and data type**

# %% [markdown]
# ## Question 2
# Create a **5 × 5 matrix** containing numbers from **1 to 25** using NumPy.
# - Extract the **third row**
# - Extract the **last column**

# %% [markdown]
# ## Question 3
# Generate **10 random integers between 10 and 100**.
# - Print the array
# - Find the **maximum, minimum, and mean** value.

# %% [markdown]
# ## Question 4
# Create two arrays:
# ```
# a = [1,2,3,4,5]
# b = [6,7,8,9,10]
# ```
# Perform the following operations:
# - Addition
# - Multiplication
# - Square of array `a`

# %% [markdown]
# ## Question 5
# Create an array containing numbers from **1 to 50**.
# - Extract all **even numbers** using NumPy operations.

# %% [markdown]
# ## Question 6
# Generate an array of **15 random numbers between 1 and 100**.
# - Find numbers **greater than 60** using Boolean masking.

# %% [markdown]
# ## Question 7
# Create the following 3×3 matrix:
#
# ```
# 1 2 3
# 4 5 6
# 7 8 9
# ```
#
# - Calculate **sum of each row**
# - Calculate **sum of each column**

# %% [markdown]
# ## Question 8 (Application Based)
# Generate marks for **30 students** using random numbers between **30 and 100**.
#
# Perform the following:
# - Calculate the **average marks**
# - Find the number of students **scoring above average**
# - Add **5 grace marks** to every student using vectorized operation.
